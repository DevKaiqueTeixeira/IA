# %% [markdown]
# <a href="https://colab.research.google.com/github/DevKaiqueTeixeira/IA/blob/main/ExercicioLista2_Python_KaiqueDeLimaTeixeira_6periodo_TurmaC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Lista 2")
# Out:
# Lista 2
